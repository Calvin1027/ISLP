# %% [markdown]
# <a href="https://colab.research.google.com/github/Calvin1027/ISLP/blob/main/Exercise_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Use the pd.read_csv()  function to read the data into Python.
#
# Call the loaded data college. Make sure that you have the directory set to the correct location for the data.

# %%
import pandas as pd
college=pd.read_csv('/content/College.csv')
college
# Out:
#                          Unnamed: 0 Private   Apps  Accept  Enroll  Top10perc  \
# 0      Abilene Christian University     Yes   1660    1232     721         23
# 1                Adelphi University     Yes   2186    1924     512         16
# 2                    Adrian College     Yes   1428    1097     336         22
# 3               Agnes Scott College     Yes    417     349     137         60
# 4         Alaska Pacific University     Yes    193     146      55         16
# ..                              ...     ...    ...     ...     ...        ...
# 772         Worcester State College      No   2197    1515     543          4
# 773               Xavier University     Yes   1959    1805     695         24
# 774  Xavier University of Louisiana     Yes   2097    1915     695         34
# 775                 Yale University     Yes  10705    2453    1317         95
# 776    York College of Pennsylvania     Yes   2989    1855     691         28
#
# ...

# %% [markdown]
# Look at the data used in the notebook by creating and running a new cell with just the code college in it. You should notice that the first column is just the name of each university in a column named something like Unnamed: 0. We don’t really want pandas to treat this as data. However, it may be handy to have these names for later. Try the following commands and similarly look at the resulting data frames:

# %%
college2=pd.read_csv('/content/College.csv',index_col=0) #college(첫번째 컬럼)의 인덱스를 0으로 지정-> 0부터 시작하게 만듦
college3=college.rename({'Unnamed: 0' : 'College'},#열 이름 변경
                        axis=1) #행의 이름을 바꿀려면 axis=0. 여기선 열의 이름을 바꾸기 때문에 axis=1

college3=college3.set_index('College')#college를 인덱스로

college3
# Out:
#                                Private   Apps  Accept  Enroll  Top10perc  \
# College
# Abilene Christian University       Yes   1660    1232     721         23
# Adelphi University                 Yes   2186    1924     512         16
# Adrian College                     Yes   1428    1097     336         22
# Agnes Scott College                Yes    417     349     137         60
# Alaska Pacific University          Yes    193     146      55         16
# ...                                ...    ...     ...     ...        ...
# Worcester State College             No   2197    1515     543          4
# Xavier University                  Yes   1959    1805     695         24
# Xavier University of Louisiana     Yes   2097    1915     695         34
# Yale University                    Yes  10705    2453    1317         95
# York College of Pennsylvania       Yes   2989    1855     691         28
#
#                                 Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# ...

# %% [markdown]
# 3. Use the describe() method of to produce a numerical summary of the variables in the data set.

# %%
college=college3
summary=college3.describe()
summary #인덱스가 college이기 때문에 college에 대한 Summary는 없다(애초에 범주형이라 통계량 계산이 불가능하기도 함)
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %% [markdown]
# 4. Use the pd.plotting.scatter_matrix() function to produce a scatterplot matrix of the first columns [Top10perc, Apps, Enroll]. Recall that you can reference a list C of columns of a data frame
# A using A[C].

# %%
pd.plotting.scatter_matrix(college[['Top10perc', 'Apps', 'Enroll']])
# Out:
# array([[<Axes: xlabel='Top10perc', ylabel='Top10perc'>,
#         <Axes: xlabel='Apps', ylabel='Top10perc'>,
#         <Axes: xlabel='Enroll', ylabel='Top10perc'>],
#        [<Axes: xlabel='Top10perc', ylabel='Apps'>,
#         <Axes: xlabel='Apps', ylabel='Apps'>,
#         <Axes: xlabel='Enroll', ylabel='Apps'>],
#        [<Axes: xlabel='Top10perc', ylabel='Enroll'>,
#         <Axes: xlabel='Apps', ylabel='Enroll'>,
#         <Axes: xlabel='Enroll', ylabel='Enroll'>]], dtype=object)

# %% [markdown]
# 5. Use the boxplot() method of college to produce side-by-side boxplots of Outstate versus Private.
#
# *   항목 추가
# *   항목 추가

# %%
import matplotlib.pyplot as plt

# 'Outstate'와 'Private' 열에 대한 상자그림 그리기
college.boxplot(column='Outstate', by='Private', figsize=(8, 6)) #private이 범주형 데이터니까 by다음에 private을 쓴다
plt.xlabel('Private')  # x축 레이블 설정
plt.ylabel('Outstate')  # y축 레이블 설정
plt.show()  # 그래프 보여주기

# %% [markdown]
# 6. Use the value_counts() method of college['Elite'] to see how many elite universities there are.
#
# Finally, use the boxplot() method again to produce side-by-side boxplots of Outstate versus Elite.

# %%
#Elite 만들기
college['Elite']=pd.cut(college['Top10perc'],
                        [0,0.5,1], #0~0.5는 No, 0.5~1은 Yes
                        labels=['No','Yes'])

pd.value_counts(college['Elite'])
# Out:
# Yes    3
# No     0
# Name: Elite, dtype: int64

# %%
college.boxplot(column='Outstate',by='Elite', figsize=(8,6))
plt.xlabel('Elite')
plt.ylabel('Outstate')
plt.show()

# %% [markdown]
# 7. Use the plot.hist() method of college to produce some his- tograms with differing numbers of bins for a few of the quanti- tative variables. The command plt.subplots(2, 2) may be use- ful: it will divide the plot window into four regions so that four plots can be made simultaneously. By changing the arguments you can divide the screen up in other combinations.

# %%
fig, axs = plt.subplots(2, 2)
college['Enroll'].plot.hist(ax=axs[0, 0])
college['Top10perc'].plot.hist(ax=axs[0, 1])
college['Outstate'].plot.hist(ax=axs[1, 0])
college['Top25perc'].plot.hist(ax=axs[1, 1])
# Out:
# <Axes: ylabel='Frequency'>

# %%
Auto=pd.read_csv('/content/Auto.data',delim_whitespace=True) #delim_whitespace=True를 해줘야 공백이 제거됨
Auto
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0      130.0  3504.0          12.0    70
# 1    15.0          8         350.0      165.0  3693.0          11.5    70
# 2    18.0          8         318.0      150.0  3436.0          11.0    70
# 3    16.0          8         304.0      150.0  3433.0          12.0    70
# 4    17.0          8         302.0      140.0  3449.0          10.5    70
# ..    ...        ...           ...        ...     ...           ...   ...
# 392  27.0          4         140.0      86.00  2790.0          15.6    82
# 393  44.0          4          97.0      52.00  2130.0          24.6    82
# 394  32.0          4         135.0      84.00  2295.0          11.6    82
# 395  28.0          4         120.0      79.00  2625.0          18.6    82
# 396  31.0          4         119.0      82.00  2720.0          19.4    82
#
#      origin                       name
# 0         1  chevrolet chevelle malibu
# ...

# %% [markdown]
# a. Which of the predictors are quantitative, and which are qualitative?
#
# -> qualitative: 'origin', 'name'. quantitative: every variable except 'origin', 'name'

# %%
pd.value_counts(Auto['origin'])
# Out:
# 1    248
# 3     79
# 2     70
# Name: origin, dtype: int64

# %% [markdown]
# b.What is the range of each quantitative predictor? You can an- swer this using the min() and max() methods in numpy.
#
# c.What is the mean and standard deviation of each quantitative predictor?

# %%
import numpy as np
min_mpg=np.min(Auto['mpg'])
min_mpg #9.0
max_mpg=np.max(Auto['mpg'])
max_mpg #46.6

mean_mpg=np.mean(Auto['mpg'])
mean_mpg #23.51586901763224

std_mpg=np.std(Auto['mpg'])
std_mpg #7.815941538224256

#이렇게 모든 변수를 다 하면 된다..
# Out:
# 7.815941538224256

# %% [markdown]
# d. Now remove the 10th through 85th observations. What is the range, mean, and standard deviation of each predictor in the subset of the data that remains?

# %%
Auto_reduced=Auto.drop(Auto.index[10:86]) #슬라이싱이니까 10~86이 아니라 10~86-1=85까지
Auto_reduced
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0      130.0  3504.0          12.0    70
# 1    15.0          8         350.0      165.0  3693.0          11.5    70
# 2    18.0          8         318.0      150.0  3436.0          11.0    70
# 3    16.0          8         304.0      150.0  3433.0          12.0    70
# 4    17.0          8         302.0      140.0  3449.0          10.5    70
# ..    ...        ...           ...        ...     ...           ...   ...
# 392  27.0          4         140.0      86.00  2790.0          15.6    82
# 393  44.0          4          97.0      52.00  2130.0          24.6    82
# 394  32.0          4         135.0      84.00  2295.0          11.6    82
# 395  28.0          4         120.0      79.00  2625.0          18.6    82
# 396  31.0          4         119.0      82.00  2720.0          19.4    82
#
#      origin                       name
# 0         1  chevrolet chevelle malibu
# ...

# %%
min_mpg=np.min(Auto_reduced['mpg'])
min_mpg #7.887612832492534

max_mpg=np.max(Auto_reduced['mpg'])
max_mpg #46.6

mean_mpg=np.mean(Auto_reduced['mpg'])
mean_mpg #24.44485981308411

std_mpg=np.std(Auto_reduced['mpg'])
std_mpg #7.887612832492534
# Out:
# 7.887612832492534

# %% [markdown]
# e. Using the full data set, investigate the predictors graphically, using scatterplots or other tools of your choice. Create some plots highlighting the relationships among the predictors. Comment on your findings.

# %%
pd.plotting.scatter_matrix(Auto[['mpg', 'cylinders', 'displacement','horsepower','weight','acceleration','year']])
# Out:
# array([[<Axes: xlabel='mpg', ylabel='mpg'>,
#         <Axes: xlabel='cylinders', ylabel='mpg'>,
#         <Axes: xlabel='displacement', ylabel='mpg'>,
#         <Axes: xlabel='weight', ylabel='mpg'>,
#         <Axes: xlabel='acceleration', ylabel='mpg'>,
#         <Axes: xlabel='year', ylabel='mpg'>],
#        [<Axes: xlabel='mpg', ylabel='cylinders'>,
#         <Axes: xlabel='cylinders', ylabel='cylinders'>,
#         <Axes: xlabel='displacement', ylabel='cylinders'>,
#         <Axes: xlabel='weight', ylabel='cylinders'>,
#         <Axes: xlabel='acceleration', ylabel='cylinders'>,
#         <Axes: xlabel='year', ylabel='cylinders'>],
#        [<Axes: xlabel='mpg', ylabel='displacement'>,
#         <Axes: xlabel='cylinders', ylabel='displacement'>,
#         <Axes: xlabel='displacement', ylabel='displacement'>,
#         <Axes: xlabel='weight', ylabel='displacement'>,
#         <Axes: xlabel='acceleration', ylabel='displacement'>,
# ...

# %% [markdown]
# 1. acceleration이 정규분포와 유사한 모양(종모양& 중심 대칭)을 따른다
# 2. mpg와 weight, displacement는 감소함수 형태의 모양을 가진다
# -> mpg가 커질수록 weight, displacement는 감소

# %% [markdown]
# f. Suppose that we wish to predict gas mileage (mpg) on the basis of the other variables. Do your plots suggest that any of the other variables might be useful in predicting mpg? Justify your answer.

# %%
fix,ax=plt.subplots(figsize=(4,4))
ax.scatter(Auto['weight'],Auto['mpg'],marker='o')
ax.set_xlabel('weight')
ax.set_ylabel('mpg')
plt.show()

fix,ax=plt.subplots(figsize=(4,4))
ax.scatter(Auto['displacement'],Auto['mpg'],marker='o')
ax.set_xlabel('displacement')
ax.set_ylabel('mpg')
plt.show()

# %% [markdown]
# 두 plot을 보면 두 변수 weight, displacement에 대해 mpg는 모두 감소함수임을 보여준다
# 즉, linear보다는 non-linear관계임을 추측해볼 수 있다

# %% [markdown]
# a. How many rows are in this data set? How many columns? What do the rows and columns represent?

# %%
import pandas as pd
boston=pd.read_csv('/content/Boston.csv')
boston
# Out:
#      Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0             1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1             2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2             3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3             4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4             5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
# ..          ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 501         502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1
# 502         503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1
# 503         504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1
# 504         505  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1
# 505         506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1
#
#      tax  ptratio  lstat  medv
# ...

# %% [markdown]
# b. How many rows are in this data set? How many columns? What do the rows and columns represent?
#
# -> It has 506 rows and 14 columns, which means several information about houses in Boston.

# %% [markdown]
# c. Make some pairwise scatterplots of the predictors (columns) in this data set. Describe your findings.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.pairplot(boston)
plt.show()

# %% [markdown]
# There is some non-linear relationship such as medv and Istat,rm and Istat. And also it has some linear relationship like rm and medv.

# %% [markdown]
# d. Are any of the predictors associated with per capita crime rate? If so, explain the relationship.
#
# -> In this plot, we need to focus on the relationship between crim and other variables. It usually has non-linear relationship like Exponential function(crime and dis, medv) and Log function(crime and nox)

# %% [markdown]
# e. Do any of the suburbs of Boston appear to have particularly high crime rates? Tax rates? Pupil-teacher ratios? Comment on the range of each predictor.

# %%
fix,ax=plt.subplots(figsize=(2,2))
ax.scatter(boston['Unnamed: 0'],boston['crim'],marker='o')
ax.set_xlabel('Unnamed: 0')
ax.set_ylabel('crim')
plt.show()

fix,ax=plt.subplots(figsize=(2,2))
ax.scatter(boston['Unnamed: 0'],boston['tax'],marker='o')
ax.set_xlabel('Unnamed: 0')
ax.set_ylabel('tax')
plt.show()


fix,ax=plt.subplots(figsize=(2,2))
ax.scatter(boston['Unnamed: 0'],boston['ptratio'])
ax.set_xlabel('Unnamed: 0')
ax.set_ylabel('ptratio')
plt.show()

# %% [markdown]
# Although ptratio is relatively random, tax and crim is not random distribution.

# %% [markdown]
# f. How many of the suburbs in this data set bound the Charles river?
#
# 35

# %%
pd.value_counts(boston['chas'])
# Out:
# 0    471
# 1     35
# Name: chas, dtype: int64

# %% [markdown]
# g. What is the median pupil-teacher ratio among the towns in this data set?
#
# -> 19.05

# %%
import numpy as np
median_boston_ptratio=np.median(boston['ptratio'])
median_boston_ptratio
# Out:
# 19.05

# %% [markdown]
# h. Which suburb of Boston has lowest median value of owner- occupied homes? What are the values of the other predictors for that suburb, and how do those values compare to the overall ranges for those predictors? Comment on your findings.

# %%
boston['medv'].idxmin()

boston['medv'].idxmin()
a=boston.describe()

condition = boston['medv'] == 19.05
filtered_boston= boston[condition]
filtered_boston#모르겠음...
# Out:
#      Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0             1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1             2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2             3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3             4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4             5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
# ..          ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 501         502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1
# 502         503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1
# 503         504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1
# 504         505  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1
# 505         506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1
#
#      tax  ptratio  lstat   medv
# ...

# %% [markdown]
# i. In this data set, how many of the suburbs average more than seven rooms per dwelling? More than eight rooms per dwelling? Comment on the suburbs that average more than eight rooms per dwelling.

# %%
len(boston[boston['rm']>7]) #64
len(boston[boston['rm']>8]) #13

boston[boston['rm']>8].describe()
# Out:
#        Unnamed: 0       crim         zn      indus       chas        nox  \
# count   13.000000  13.000000  13.000000  13.000000  13.000000  13.000000
# mean   232.307692   0.718795  13.615385   7.078462   0.153846   0.539238
# std     60.915768   0.901640  26.298094   5.392767   0.375534   0.092352
# min     98.000000   0.020090   0.000000   2.680000   0.000000   0.416100
# 25%    225.000000   0.331470   0.000000   3.970000   0.000000   0.504000
# 50%    233.000000   0.520140   0.000000   6.200000   0.000000   0.507000
# 75%    258.000000   0.578340  20.000000   6.200000   0.000000   0.605000
# max    365.000000   3.474280  95.000000  19.580000   1.000000   0.718000
#
#               rm        age        dis        rad         tax    ptratio  \
# count  13.000000  13.000000  13.000000  13.000000   13.000000  13.000000
# mean    8.348538  71.538462   3.430192   7.461538  325.076923  16.361538
# std     0.251261  24.608723   1.883955   5.332532  110.971063   2.410580
# ...

# %%
boston.describe()
# Out:
#        Unnamed: 0        crim          zn       indus        chas         nox  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean   253.500000    3.613524   11.363636   11.136779    0.069170    0.554695
# std    146.213884    8.601545   23.322453    6.860353    0.253994    0.115878
# min      1.000000    0.006320    0.000000    0.460000    0.000000    0.385000
# 25%    127.250000    0.082045    0.000000    5.190000    0.000000    0.449000
# 50%    253.500000    0.256510    0.000000    9.690000    0.000000    0.538000
# 75%    379.750000    3.677083   12.500000   18.100000    0.000000    0.624000
# max    506.000000   88.976200  100.000000   27.740000    1.000000    0.871000
#
#                rm         age         dis         rad         tax     ptratio  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     6.284634   68.574901    3.795043    9.549407  408.237154   18.455534
# ...

# %% [markdown]
# crim, tax of suburbs that average more than eight rooms per dwellings is more larger.
